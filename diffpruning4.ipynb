# %% [markdown]
# # Diff-Pruning — DDPM CIFAR-10

# %%
# !git clone --branch clean https://github.com/elliotcanter11/Diff-Pruning.git
# Out:
# Cloning into 'Diff-Pruning'...
# remote: Enumerating objects: 1089, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 1089 (delta 85), reused 70 (delta 70), pack-reused 1001 (from 1)
# Receiving objects: 100% (1089/1089), 28.19 MiB | 20.25 MiB/s, done.
# Resolving deltas: 100% (540/540), done.

# %%
# %cd Diff-Pruning/
# Out:
# /content/Diff-Pruning

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: torchvision>=0.13.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (0.26.0+cu128)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (1.16.3)
# Requirement already satisfied: torch>=1.12.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.11.0+cu128)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (4.67.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (2.0.2)
# Collecting torch_pruning (from -r requirements.txt (line 7))
#   Downloading torch_pruning-1.6.1-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (1.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate->-r requirements.txt (line 1)) (26.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate->-r requirements.txt (line 1)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate->-r requirements.txt (line 1)) (6.0.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate->-r requirements.txt (line 1)) (0.8.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision>=0.13.1->-r requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements.txt (line 4)) (3.29.7)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements.txt (line 4)) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements.txt (line 4)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements.txt (line 4)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements.txt (line 4)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements.txt (line 4)) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.12.1->-r requirements.txt (line 4)) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements.txt (line 4)) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements.txt (line 4)) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements.txt (line 4)) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements.txt (line 4)) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.1->-r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.12.1->-r requirements.txt (line 4)) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.12.1->-r requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.12.1->-r requirements.txt (line 4)) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.12.1->-r requirements.txt (line 4)) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.12.1->-r requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.12.1->-r requirements.txt (line 4)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.12.1->-r requirements.txt (line 4)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.12.1->-r requirements.txt (line 4)) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.12.1->-r requirements.txt (line 4)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.12.1->-r requirements.txt (line 4)) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.12.1->-r requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r requirements.txt (line 8)) (8.4.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r requirements.txt (line 8)) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r requirements.txt (line 8)) (0.28.1)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.12.1->-r requirements.txt (line 4)) (1.5.6)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->-r requirements.txt (line 8)) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->-r requirements.txt (line 8)) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->-r requirements.txt (line 8)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->-r requirements.txt (line 8)) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->-r requirements.txt (line 8)) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.12.1->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.12.1->-r requirements.txt (line 4)) (3.0.3)
# Downloading torch_pruning-1.6.1-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 7.7 MB/s eta 0:00:00
# Installing collected packages: torch_pruning
# Successfully installed torch_pruning-1.6.1

# %% [markdown]
# ## Data & pretrained model

# %%
# Download and extract CIFAR-10 images to data/cifar10_images for training and evaluation.
# !python tools/extract_cifar10_hug.py --output data
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md: 100% 5.16k/5.16k [00:00<00:00, 12.6MB/s]
#
# plain_text/train-00000-of-00001.parquet: downloading bytes:  92% 110M/120M [00:02<00:00, 96.3MB/s, 9.13MB/s  ]
# plain_text/train-00000-of-00001.parquet: downloading bytes: 100% 117M/117M [00:02<00:00, 52.8MB/s, 10.8MB/s  ]
# plain_text/train-00000-of-00001.parquet: reconstructing file: 100% 120M/120M [00:02<00:00, 54.2MB/s, 11.4MB/s  ]
#
# plain_text/test-00000-of-00001.parquet: downloading bytes:  53% 12.8M/23.9M [00:01<00:00, 11.5MB/s,  210kB/s  ]
# plain_text/test-00000-of-00001.parquet: downloading bytes: 100% 23.3M/23.3M [00:01<00:00, 15.2MB/s, 2.24MB/s  ]
# plain_text/test-00000-of-00001.parquet: reconstructing file: 100% 23.9M/23.9M [00:01<00:00, 15.6MB/s, 2.31MB/s  ]
# Generating train split: 100% 50000/50000 [00:00<00:00, 195849.27 examples/s]
# Generating test split: 100% 10000/10000 [00:00<00:00, 228194.38 examples/s]
# 100% 50000/50000 [00:29<00:00, 1695.54it/s]

# %%
# Download an official DDPM model and convert it to the Huggingface Diffusers format.
# The converted (EMA) model of google/ddpm-cifar10-32 lands in pretrained/ddpm_ema_cifar10.
# !bash tools/convert_cifar10_ddpm_ema.sh
# Out:
# --2026-08-03 15:10:24--  https://heibox.uni-heidelberg.de/f/2e4f01e2d9ee49bab1d5/?dl=1
# Resolving heibox.uni-heidelberg.de (heibox.uni-heidelberg.de)... 129.206.7.113
# Connecting to heibox.uni-heidelberg.de (heibox.uni-heidelberg.de)|129.206.7.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://heibox.uni-heidelberg.de/seafhttp/files/4c0a3382-2187-40cc-9042-b4cd5855238b/model-790000.ckpt [following]
# --2026-08-03 15:10:25--  https://heibox.uni-heidelberg.de/seafhttp/files/4c0a3382-2187-40cc-9042-b4cd5855238b/model-790000.ckpt
# Reusing existing connection to heibox.uni-heidelberg.de:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 143046049 (136M) [application/octet-stream]
# Saving to: ‘pretrained/cifar10-ema-model-790000.ckpt’
#
# pretrained/cifar10- 100%[===================>] 136.42M  5.22MB/s    in 24s
#
# 2026-08-03 15:10:51 (5.57 MB/s) - ‘pretrained/cifar10-ema-model-790000.ckpt’ saved [143046049/143046049]
#
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# odict_keys(['temb.dense.0.weight', 'temb.dense.0.bias', 'temb.dense.1.weight', 'temb.dense.1.bias', 'conv_in.weight', 'conv_in.bias', 'down.0.block.0.norm1.weight', 'down.0.block.0.norm1.bias', 'down.0.block.0.conv1.weight', 'down.0.block.0.conv1.bias', 'down.0.block.0.temb_proj.weight', 'down.0.block.0.temb_proj.bias', 'down.0.block.0.norm2.weight', 'down.0.block.0.norm2.bias', 'down.0.block.0.conv2.weight', 'down.0.block.0.conv2.bias', 'down.0.block.1.norm1.weight', 'down.0.block.1.norm1.bias', 'down.0.block.1.conv1.weight', 'down.0.block.1.conv1.bias', 'down.0.block.1.temb_proj.weight', 'down.0.block.1.temb_proj.bias', 'down.0.block.1.norm2.weight', 'down.0.block.1.norm2.bias', 'down.0.block.1.conv2.weight', 'down.0.block.1.conv2.bias', 'down.0.downsample.conv.weight', 'down.0.downsample.conv.bias', 'down.1.block.0.norm1.weight', 'down.1.block.0.norm1.bias', 'down.1.block.0.conv1.weight', 'down.1.block.0.conv1.bias', 'down.1.block.0.temb_proj.weight', 'down.1.block.0.temb_proj.bias', 'down.1.block.0.norm2.weight', 'down.1.block.0.norm2.bias', 'down.1.block.0.conv2.weight', 'down.1.block.0.conv2.bias', 'down.1.block.0.nin_shortcut.weight', 'down.1.block.0.nin_shortcut.bias', 'down.1.block.1.norm1.weight', 'down.1.block.1.norm1.bias', 'down.1.block.1.conv1.weight', 'down.1.block.1.conv1.bias', 'down.1.block.1.temb_proj.weight', 'down.1.block.1.temb_proj.bias', 'down.1.block.1.norm2.weight', 'down.1.block.1.norm2.bias', 'down.1.block.1.conv2.weight', 'down.1.block.1.conv2.bias', 'down.1.attn.0.norm.weight', 'down.1.attn.0.norm.bias', 'down.1.attn.0.q.weight', 'down.1.attn.0.q.bias', 'down.1.attn.0.k.weight', 'down.1.attn.0.k.bias', 'down.1.attn.0.v.weight', 'down.1.attn.0.v.bias', 'down.1.attn.0.proj_out.weight', 'down.1.attn.0.proj_out.bias', 'down.1.attn.1.norm.weight', 'down.1.attn.1.norm.bias', 'down.1.attn.1.q.weight', 'down.1.attn.1.q.bias', 'down.1.attn.1.k.weight', 'down.1.attn.1.k.bias', 'down.1.attn.1.v.weight', 'down.1.attn.1.v.bias', 'down.1.attn.1.proj_out.weight', 'down.1.attn.1.proj_out.bias', 'down.1.downsample.conv.weight', 'down.1.downsample.conv.bias', 'down.2.block.0.norm1.weight', 'down.2.block.0.norm1.bias', 'down.2.block.0.conv1.weight', 'down.2.block.0.conv1.bias', 'down.2.block.0.temb_proj.weight', 'down.2.block.0.temb_proj.bias', 'down.2.block.0.norm2.weight', 'down.2.block.0.norm2.bias', 'down.2.block.0.conv2.weight', 'down.2.block.0.conv2.bias', 'down.2.block.1.norm1.weight', 'down.2.block.1.norm1.bias', 'down.2.block.1.conv1.weight', 'down.2.block.1.conv1.bias', 'down.2.block.1.temb_proj.weight', 'down.2.block.1.temb_proj.bias', 'down.2.block.1.norm2.weight', 'down.2.block.1.norm2.bias', 'down.2.block.1.conv2.weight', 'down.2.block.1.conv2.bias', 'down.2.downsample.conv.weight', 'down.2.downsample.conv.bias', 'down.3.block.0.norm1.weight', 'down.3.block.0.norm1.bias', 'down.3.block.0.conv1.weight', 'down.3.block.0.conv1.bias', 'down.3.block.0.temb_proj.weight', 'down.3.block.0.temb_proj.bias', 'down.3.block.0.norm2.weight', 'down.3.block.0.norm2.bias', 'down.3.block.0.conv2.weight', 'down.3.block.0.conv2.bias', 'down.3.block.1.norm1.weight', 'down.3.block.1.norm1.bias', 'down.3.block.1.conv1.weight', 'down.3.block.1.conv1.bias', 'down.3.block.1.temb_proj.weight', 'down.3.block.1.temb_proj.bias', 'down.3.block.1.norm2.weight', 'down.3.block.1.norm2.bias', 'down.3.block.1.conv2.weight', 'down.3.block.1.conv2.bias', 'mid.block_1.norm1.weight', 'mid.block_1.norm1.bias', 'mid.block_1.conv1.weight', 'mid.block_1.conv1.bias', 'mid.block_1.temb_proj.weight', 'mid.block_1.temb_proj.bias', 'mid.block_1.norm2.weight', 'mid.block_1.norm2.bias', 'mid.block_1.conv2.weight', 'mid.block_1.conv2.bias', 'mid.attn_1.norm.weight', 'mid.attn_1.norm.bias', 'mid.attn_1.q.weight', 'mid.attn_1.q.bias', 'mid.attn_1.k.weight', 'mid.attn_1.k.bias', 'mid.attn_1.v.weight', 'mid.attn_1.v.bias', 'mid.attn_1.proj_out.weight', 'mid.attn_1.proj_out.bias', 'mid.block_2.norm1.weight', 'mid.block_2.norm1.bias', 'mid.block_2.conv1.weigh ...
# /usr/local/lib/python3.12/dist-packages/diffusers/configuration_utils.py:282: FutureWarning: It is deprecated to pass a pretrained model name or path to `from_config`.If you were trying to load a scheduler, please use <class 'diffusers.schedulers.scheduling_ddpm.DDPMScheduler'>.from_pretrained(...) instead. Otherwise, please make sure to pass a configuration dictionary instead. This functionality will be removed in v1.0.0.
#   deprecate("config-passed-as-path", "1.0.0", deprecation_message, standard_warn=False)
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# scheduler_config.json: 100% 256/256 [00:00<00:00, 1.11MB/s]

# %%
# !python ddpm_sample.py --output_dir run/sample/ddpm_cifar10_pretrained --batch_size 16 --total_samples 16 --model_path pretrained/ddpm_ema_cifar10
# Out:
# Loading model from pretrained/ddpm_ema_cifar10
# The config attributes {'attn_norm_num_groups': None, 'downsample_type': 'conv', 'dropout': 0.0, 'mid_block_type': 'UNetMidBlock2D', 'num_train_timesteps': None, 'time_embedding_dim': None, 'upsample_type': 'conv'} were passed to UNet2DModel, but are not expected and will be ignored. Please verify your config.json configuration file.
# The config attributes {'rescale_betas_zero_snr': False, 'timestep_spacing': 'leading'} were passed to DDIMScheduler, but are not expected and will be ignored. Please verify your scheduler_config.json configuration file.
# The config attributes {'rescale_betas_zero_snr': False, 'timestep_spacing': 'leading'} were passed to DDIMScheduler, but are not expected and will be ignored. Please verify your scheduler_config.json configuration file.
# Warning! No positional inputs found for a module, assuming batch size is 1.
# MACS: 6.06413504 G, Params: 35.746307 M
# Samping 16x1=16 images with 1 process(es)
#   0% 0/1 [00:00<?, ?it/s]
#   0% 0/100 [00:00<?, ?it/s]
#   1% 1/100 [00:00<00:18,  5.23it/s]
#   6% 6/100 [00:00<00:03, 23.83it/s]
#  11% 11/100 [00:00<00:02, 32.66it/s]
#  16% 16/100 [00:00<00:02, 37.67it/s]
#  21% 21/100 [00:00<00:01, 40.58it/s]
#  26% 26/100 [00:00<00:01, 42.25it/s]
#  31% 31/100 [00:00<00:01, 43.64it/s]
#  36% 36/100 [00:00<00:01, 44.30it/s]
#  41% 41/100 [00:01<00:01, 44.95it/s]
#  46% 46/100 [00:01<00:01, 45.34it/s]
#  51% 51/100 [00:01<00:01, 45.50it/s]
#  56% 56/100 [00:01<00:00, 45.81it/s]
#  61% 61/100 [00:01<00:00, 45.80it/s]
#  66% 66/100 [00:01<00:00, 46.06it/s]
#  71% 71/100 [00:01<00:00, 46.07it/s]
#  76% 76/100 [00:01<00:00, 45.93it/s]
#  81% 81/100 [00:01<00:00, 46.00it/s]
#  86% 86/100 [00:02<00:00, 46.06it/s]
#  91% 91/100 [00:02<00:00, 46.33it/s]
# 100% 100/100 [00:02<00:00, 42.91it/s]
# 100% 1/1 [00:02<00:00,  2.36s/it]
# Saved 16 samples to run/sample/ddpm_cifar10_pretrained

# %%
import matplotlib.pyplot as plt
from PIL import Image

img = Image.open("run/sample/ddpm_cifar10_pretrained/process_0/10.png")
#img = Image.open("run/sample/ddpm_cifar10_pruned_raw/process_0/10.png")

plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Prune
#
# Creates a pruned model at `run/pruned/ddpm_cifar10_pruned`. The argument is the pruning ratio
# (0.1 = light, for a fast test; use 0.3 to reproduce the paper's baseline).

# %%
# !bash scripts/prune_ddpm_cifar10.sh 0.2  # pruning ratio
# Out:
# Loading pretrained model from pretrained/ddpm_ema_cifar10
# The config attributes {'attn_norm_num_groups': None, 'downsample_type': 'conv', 'dropout': 0.0, 'mid_block_type': 'UNetMidBlock2D', 'num_train_timesteps': None, 'time_embedding_dim': None, 'upsample_type': 'conv'} were passed to UNet2DModel, but are not expected and will be ignored. Please verify your config.json configuration file.
# The config attributes {'rescale_betas_zero_snr': False, 'timestep_spacing': 'leading'} were passed to DDPMScheduler, but are not expected and will be ignored. Please verify your scheduler_config.json configuration file.
# /usr/local/lib/python3.12/dist-packages/torch_pruning/pruner/algorithms/base_pruner.py:106: UserWarning: channel_groups is deprecated. Please use in_channel_groups and out_channel_groups instead.
#   warnings.warn(
# Warning! No positional inputs found for a module, assuming batch size is 1.
# Warning! No positional inputs found for a module, assuming batch size is 1.
# UNet2DModel(
#   (conv_in): Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (time_proj): Timesteps()
#   (time_embedding): TimestepEmbedding(
#     (linear_1): Linear(in_features=128, out_features=409, bias=True)
#     (act): SiLU()
#     (linear_2): Linear(in_features=409, out_features=409, bias=True)
#   )
#   (down_blocks): ModuleList(
#     (0): DownBlock2D(
#       (resnets): ModuleList(
#         (0-1): 2 x ResnetBlock2D(
#           (norm1): GroupNorm(32, 96, eps=1e-06, affine=True)
#           (conv1): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=409, out_features=96, bias=True)
#           (norm2): GroupNorm(32, 96, eps=1e-06, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#         )
#       )
#       (downsamplers): ModuleList(
#         (0): Downsample2D(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2))
#         )
#       )
#     )
#     (1): AttnDownBlock2D(
#       (attentions): ModuleList(
#         (0-1): 2 x Attention(
#           (group_norm): GroupNorm(32, 192, eps=1e-06, affine=True)
#           (to_q): Linear(in_features=192, out_features=204, bias=True)
#           (to_k): Linear(in_features=192, out_features=204, bias=True)
#           (to_v): Linear(in_features=192, out_features=204, bias=True)
#           (to_out): ModuleList(
#             (0): Linear(in_features=204, out_features=192, bias=True)
#             (1): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (resnets): ModuleList(
#         (0): ResnetBlock2D(
#           (norm1): GroupNorm(32, 96, eps=1e-06, affine=True)
#           (conv1): Conv2d(96, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=409, out_features=192, bias=True)
#           (norm2): GroupNorm(32, 192, eps=1e-06, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): ResnetBlock2D(
#           (norm1): GroupNorm(32, 192, eps=1e-06, affine=True)
#           (conv1): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=409, out_features=192, bias=True)
#           (norm2): GroupNorm(32, 192, eps=1e-06, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#         )
#       )
#       (downsamplers): ModuleList(
#         (0): Downsample2D(
#           (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2))
#         )
#       )
#     )
#     (2): DownBlock2D(
#       (resnets): ModuleList(
#         (0-1): 2 x ResnetBlock2D(
#           (norm1): GroupNorm(32, 192, eps=1e-06, affine=True)
#           (conv1): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=409, out_features=192, bias=True)
#           (norm2): GroupNorm(32, 192, eps=1e-06, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#         )
#       )
#       (downsamplers): ModuleList(
#         (0): Downsample2D(
#           (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2))
#         )
#       )
#     )
#     (3): DownBlock2D(
#       (resnets): ModuleList(
#         (0-1): 2 x ResnetBlock2D(
#           (norm1): GroupNorm(32, 192, eps=1e-06, affine=True)
#           (conv1): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=409, out_features=192, bias=True)
#           (norm2): GroupNorm(32, 192, eps=1e-06, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#         )
#       )
#     )
#   )
#   (up_blocks): ModuleList(
#     (0-1): 2 x UpBlock2D(
#       (resnets): ModuleList(
#         (0-1): 2 x ResnetBlock2D(
#           (norm1): GroupNorm(32, 384, eps=1e-06, affine=True)
#           (conv1): Conv2d(384, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=409, out_features=192, bias=True)
#           (norm2): GroupNorm(32, 192, eps=1e-06, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): ResnetBlock2D(
#           (norm1): GroupNorm(32, 384, eps=1e-06, affine=True)
#           (conv1): Conv2d(384, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=409, out_features=192, bias=True)
#           (norm2): GroupNorm(32, 192, eps=1e-06, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(192, 204, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(384, 204, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (upsamplers): ModuleList(
#         (0): Upsample2D(
#           (conv): Conv2d(204, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#     )
#     (2): AttnUpBlock2D(
#       (attentions): ModuleList(
#         (0-2): 3 x Attention(
#           (group_norm): GroupNorm(32, 192, eps=1e-06, affine=True)
#           (to_q): Linear(in_features=192, out_features=204, bias=True)
#           (to_k): Linear(in_features=192, out_features=204, bias=True)
#           (to_v): Linear(in_features=192, out_features=204, bias=True)
#           (to_out): ModuleList(
#             (0): Linear(in_features=204, out_features=192, bias=True)
#             (1): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (resnets): ModuleList(
#         (0-1): 2 x ResnetBlock2D(
#           (norm1): GroupNorm(32, 384, eps=1e-06, affine=True)
#           (conv1): Conv2d(384, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=409, out_features=192, bias=True)
#           (norm2): GroupNorm(32, 192, eps=1e-06, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): ResnetBlock2D(
#           (norm1): GroupNorm(32, 288, eps=1e-06, affine=True)
#           (conv1): Conv2d(288, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=409, out_features=192, bias=True)
#           (norm2): GroupNorm(32, 192, eps=1e-06, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(288, 192, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (upsamplers): ModuleList(
#         (0): Upsample2D(
#           (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#     )
#     (3): UpBlock2D(
#       (resnets): ModuleList(
#         (0): ResnetBlock2D(
#           (norm1): GroupNorm(32, 288, eps=1e-06, affine=True)
#           (conv1): Conv2d(288, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=409, out_features=96, bias=True)
#           (norm2): GroupNorm(32, 96, eps=1e-06, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(288, 96, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1-2): 2 x ResnetBlock2D(
#           (norm1): GroupNorm(32, 192, eps=1e-06, affine=True)
#           (conv1): Conv2d(192, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (time_emb_proj): Linear(in_features=409, out_features=96, bias=True)
#           (norm2): GroupNorm(32, 96, eps=1e-06, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#           (conv_shortcut): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#     )
#   )
#   (mid_block): UNetMidBlock2D(
#     (attentions): ModuleList(
#       (0): Attention(
#         (group_norm): GroupNorm(32, 192, eps=1e-06, affine=True)
#         (to_q): Linear(in_features=192, out_features=204, bias=True)
#         (to_k): Linear(in_features=192, out_features=204, bias=True)
#         (to_v): Linear(in_features=192, out_features=204, bias=True)
#         (to_out): ModuleList(
#           (0): Linear(in_features=204, out_features=192, bias=True)
#           (1): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (resnets): ModuleList(
#       (0-1): 2 x ResnetBlock2D(
#         (norm1): GroupNorm(32, 192, eps=1e-06, affine=True)
#         (conv1): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (time_emb_proj): Linear(in_features=409, out_features=192, bias=True)
#         (norm2): GroupNorm(32, 192, eps=1e-06, affine=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#         (conv2): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (nonlinearity): SiLU()
#       )
#     )
#   )
#   (conv_norm_out): GroupNorm(32, 96, eps=1e-06, affine=True)
#   (conv_act): SiLU()
#   (conv_out): Conv2d(96, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )
# #Params: 35.7463 M => 20.3956 M
# #MACS: 6.0641 G => 3.4351 G
# The config attributes {'rescale_betas_zero_snr': False, 'timestep_spacing': 'leading'} were passed to DDIMScheduler, but are not expected and will be ignored. Please verify your scheduler_config.json configuration file.
# The config attributes {'rescale_betas_zero_snr': False, 'timestep_spacing': 'leading'} were passed to DDIMScheduler, but are not expected and will be ignored. Please verify your scheduler_config.json configuration file.
# 100% 100/100 [00:11<00:00,  8.78it/s]

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("run/pruned/ddpm_cifar10_pruned/vis/after_pruning.png")

plt.figure(figsize=(10, 10))
plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Fine-tune
#
# Recovers quality lost to pruning and saves to `run/finetuned/ddpm_cifar10_pruned_post_training`.
# The argument is the number of iterations (`num_iters`). 3000 is a quick sanity run; the baseline uses 100000.
#
# Checkpoints are written every `save_model_steps` (1000), so Colab persistence / resuming across a dropped
# session is possible from the last saved checkpoint.

# %%
# !bash scripts/finetune_ddpm_cifar10.sh 10000 12 > train.log 2>&1 & #num_iters, dataloader_num_workers

# %%
# !tail -n 20 train.log
# Out:
#  36%|███▌      | 36/100 [00:01<00:01, 35.00it/s]
#  40%|████      | 40/100 [00:01<00:01, 35.03it/s]
#  44%|████▍     | 44/100 [00:01<00:01, 34.98it/s]
#  48%|████▊     | 48/100 [00:01<00:01, 34.04it/s]
#  52%|█████▏    | 52/100 [00:01<00:01, 34.05it/s]
#  56%|█████▌    | 56/100 [00:01<00:01, 33.98it/s]
#  60%|██████    | 60/100 [00:01<00:01, 33.65it/s]
#  64%|██████▍   | 64/100 [00:01<00:01, 33.61it/s]
#  68%|██████▊   | 68/100 [00:01<00:00, 34.08it/s]
#  72%|███████▏  | 72/100 [00:02<00:00, 34.18it/s]
#  76%|███████▌  | 76/100 [00:02<00:00, 34.54it/s]
#  80%|████████  | 80/100 [00:02<00:00, 34.82it/s]
#  84%|████████▍ | 84/100 [00:02<00:00, 35.06it/s]
#  88%|████████▊ | 88/100 [00:02<00:00, 35.37it/s]
#  92%|█████████▏| 92/100 [00:02<00:00, 35.44it/s]
#  96%|█████████▌| 96/100 [00:02<00:00, 35.49it/s]
# 100%|██████████| 100/100 [00:02<00:00, 34.65it/s]
# Epoch 5: 100%|██████████| 391/391 [01:55<00:00,  3.39it/s, ema_decay=0.996, loss=90.2, lr=0.0002, step=2346]
# Epoch 6: 100%|██████████| 391/391 [01:51<00:00,  3.51it/s, ema_decay=0.997, loss=125, lr=0.0002, step=2737]
# Epoch 7:  26%|██▋       | 103/391 [00:29<01:21,  3.53it/s, ema_decay=0.997, loss=82.9, lr=0.0002, step=2840]

# %%
# !python ddpm_sample.py --output_dir run/sample/ddpm_cifar10_pruned_raw --batch_size 16 --total_samples 16 --pruned_model_ckpt run/finetuned/ddpm_cifar10_pruned_post_training/pruned/unet_pruned.pth --model_path run/finetuned/ddpm_cifar10_pruned_post_training --skip_type uniform
# Out:
# Loading pruned model from run/finetuned/ddpm_cifar10_pruned_post_training/pruned/unet_pruned.pth
# The config attributes {'rescale_betas_zero_snr': False, 'timestep_spacing': 'leading'} were passed to DDIMScheduler, but are not expected and will be ignored. Please verify your scheduler_config.json configuration file.
# The config attributes {'rescale_betas_zero_snr': False, 'timestep_spacing': 'leading'} were passed to DDIMScheduler, but are not expected and will be ignored. Please verify your scheduler_config.json configuration file.
# Warning! No positional inputs found for a module, assuming batch size is 1.
# MACS: 4.253761666 G, Params: 27.559129 M
# Samping 16x1=16 images with 1 process(es)
#   0% 0/1 [00:00<?, ?it/s]
#   0% 0/100 [00:00<?, ?it/s]
#   1% 1/100 [00:00<00:10,  9.10it/s]
#   5% 5/100 [00:00<00:04, 22.41it/s]
#   8% 8/100 [00:00<00:03, 24.88it/s]
#  11% 11/100 [00:00<00:03, 26.21it/s]
#  14% 14/100 [00:00<00:03, 27.26it/s]
#  18% 18/100 [00:00<00:02, 28.42it/s]
#  21% 21/100 [00:00<00:02, 28.06it/s]
#  24% 24/100 [00:00<00:02, 28.21it/s]
#  27% 27/100 [00:01<00:02, 27.90it/s]
#  30% 30/100 [00:01<00:02, 28.07it/s]
#  33% 33/100 [00:01<00:02, 28.31it/s]
#  36% 36/100 [00:01<00:02, 28.38it/s]
#  39% 39/100 [00:01<00:02, 28.32it/s]
#  42% 42/100 [00:01<00:02, 28.42it/s]
#  45% 45/100 [00:01<00:01, 28.33it/s]
#  48% 48/100 [00:01<00:01, 28.39it/s]
#  52% 52/100 [00:01<00:01, 29.36it/s]
#  55% 55/100 [00:01<00:01, 28.43it/s]
#  58% 58/100 [00:02<00:01, 28.42it/s]
#  61% 61/100 [00:02<00:01, 28.47it/s]
#  64% 64/100 [00:02<00:01, 28.53it/s]
#  67% 67/100 [00:02<00:01, 28.90it/s]
#  71% 71/100 [00:02<00:00, 29.85it/s]
#  74% 74/100 [00:02<00:00, 29.08it/s]
#  77% 77/100 [00:02<00:00, 28.91it/s]
#  80% 80/100 [00:02<00:00, 28.76it/s]
#  83% 83/100 [00:02<00:00, 28.62it/s]
#  86% 86/100 [00:03<00:00, 27.58it/s]
#  89% 89/100 [00:03<00:00, 27.73it/s]
#  92% 92/100 [00:03<00:00, 27.92it/s]
#  95% 95/100 [00:03<00:00, 28.10it/s]
# 100% 100/100 [00:03<00:00, 27.98it/s]
# 100% 1/1 [00:03<00:00,  3.60s/it]
# Saved 16 samples to run/sample/ddpm_cifar10_pruned_raw

# %%
# !ls run/sample/ddpm_cifar10_pruned_raw/process_0
# Out:
# 0.png	11.png	13.png	15.png	2.png  4.png  6.png  8.png
# 10.png	12.png	14.png	1.png	3.png  5.png  7.png  9.png

# %%
import glob
import re
from PIL import Image
import matplotlib.pyplot as plt

vis_dir = "run/finetuned/ddpm_cifar10_pruned_post_training/vis"
paths = glob.glob(f"{vis_dir}/iter-*.png")

# sort by the step number embedded in the filename
paths.sort(key=lambda p: int(re.search(r"iter-(\d+)\.png", p).group(1)))

fig, axes = plt.subplots(1, len(paths), figsize=(5 * len(paths), 5))
if len(paths) == 1:
    axes = [axes]

for ax, path in zip(axes, paths):
    step = re.search(r"iter-(\d+)\.png", path).group(1)
    img = Image.open(path)
    ax.imshow(img)
    ax.set_title(f"step {step}")
    ax.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Sample

# %%
# Pruned + finetuned: sample and save images to run/sample/ddpm_cifar10_pruned
# !bash scripts/sample_ddpm_cifar10_pruned.sh 2000 256 > sample1.log 2>&1 &

# %%
# !tail -n 20 sample1.log
# Out:
#  83%|████████▎ | 83/100 [00:32<00:06,  2.58it/s]
#  84%|████████▍ | 84/100 [00:32<00:06,  2.57it/s]
#  85%|████████▌ | 85/100 [00:32<00:05,  2.55it/s]
#  86%|████████▌ | 86/100 [00:33<00:05,  2.55it/s]
#  87%|████████▋ | 87/100 [00:33<00:05,  2.55it/s]
#  88%|████████▊ | 88/100 [00:33<00:04,  2.57it/s]
#  89%|████████▉ | 89/100 [00:34<00:04,  2.56it/s]
#  90%|█████████ | 90/100 [00:34<00:03,  2.57it/s]
#  91%|█████████ | 91/100 [00:35<00:03,  2.57it/s]
#  92%|█████████▏| 92/100 [00:35<00:03,  2.54it/s]
#  93%|█████████▎| 93/100 [00:35<00:02,  2.55it/s]
#  94%|█████████▍| 94/100 [00:36<00:02,  2.55it/s]
#  95%|█████████▌| 95/100 [00:36<00:01,  2.57it/s]
#  96%|█████████▌| 96/100 [00:37<00:01,  2.55it/s]
#  97%|█████████▋| 97/100 [00:37<00:01,  2.55it/s]
#  98%|█████████▊| 98/100 [00:37<00:00,  2.60it/s]
#  99%|█████████▉| 99/100 [00:38<00:00,  2.58it/s]
# 100%|██████████| 100/100 [00:38<00:00,  2.59it/s]
# 100%|██████████| 15/15 [09:28<00:00, 37.88s/it]
# Saved 1920 samples to run/sample/ddpm_cifar10_pruned

# %%
# Pretrained baseline: sample and save images to run/sample/ddpm_cifar10_pretrained
# !bash scripts/sample_ddpm_cifar10_pretrained.sh 2000 256 > sample2.log 2>&1 &

# %%
# !tail -n 20 sample2.log
# Out:
#  83%|████████▎ | 83/100 [00:28<00:05,  2.89it/s]
#  84%|████████▍ | 84/100 [00:28<00:05,  2.91it/s]
#  85%|████████▌ | 85/100 [00:29<00:05,  2.87it/s]
#  86%|████████▌ | 86/100 [00:29<00:04,  2.90it/s]
#  87%|████████▋ | 87/100 [00:29<00:04,  2.86it/s]
#  88%|████████▊ | 88/100 [00:30<00:04,  2.88it/s]
#  89%|████████▉ | 89/100 [00:30<00:03,  2.86it/s]
#  90%|█████████ | 90/100 [00:30<00:03,  2.87it/s]
#  91%|█████████ | 91/100 [00:31<00:03,  2.86it/s]
#  92%|█████████▏| 92/100 [00:31<00:02,  2.89it/s]
#  93%|█████████▎| 93/100 [00:31<00:02,  2.91it/s]
#  94%|█████████▍| 94/100 [00:32<00:02,  2.86it/s]
#  95%|█████████▌| 95/100 [00:32<00:01,  2.89it/s]
#  96%|█████████▌| 96/100 [00:33<00:01,  2.86it/s]
#  97%|█████████▋| 97/100 [00:33<00:01,  2.89it/s]
#  98%|█████████▊| 98/100 [00:33<00:00,  2.86it/s]
#  99%|█████████▉| 99/100 [00:34<00:00,  2.88it/s]
# 100%|██████████| 100/100 [00:34<00:00,  2.91it/s]
# 100%|██████████| 15/15 [11:44<00:00, 46.98s/it]
# Saved 1920 samples to run/sample/ddpm_cifar10_pretrained

# %% [markdown]
# ## Evaluate (FID)
#
# Using 2000 samples for fast iteration instead of the paper's 50k. Good enough to compare runs
# against each other; treat the absolute number as biased/noisy, not literature-comparable.

# %%
# Pre-compute the stats of the CIFAR-10 dataset
# !python fid_score.py --save-stats data/cifar10_images run/fid_stats_cifar10.npz --device cuda:0 --batch-size 256
# Out:
# Downloading: "https://github.com/mseitzer/pytorch-fid/releases/download/fid_weights/pt_inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/pt_inception-2015-12-05-6726825d.pth
# 100% 91.2M/91.2M [00:02<00:00, 34.0MB/s]
# Saving statistics for data/cifar10_images
# Found 50000 files.
# 100% 196/196 [03:03<00:00,  1.07it/s]

# %%
# Compute the FID score of the sampled images
# !python fid_score.py run/sample/ddpm_cifar10_pruned run/fid_stats_cifar10.npz --device cuda:0 --batch-size 256
# Out:
# Found 1920 files.
# 100% 8/8 [00:07<00:00,  1.06it/s]
# /content/Diff-Pruning/fid_score.py:218: DeprecationWarning: The `disp` argument is deprecated and will be removed in SciPy 1.18.0.
#   covmean, _ = linalg.sqrtm(sigma1.dot(sigma2), disp=False)
# FID:  27.63852081476739

# %%
# Compute the FID score of pretrained model
# !python fid_score.py run/sample/ddpm_cifar10_pretrained run/fid_stats_cifar10.npz --device cuda:0 --batch-size 256
# Out:
# Found 1920 files.
# 100% 8/8 [00:07<00:00,  1.06it/s]
# /content/Diff-Pruning/fid_score.py:218: DeprecationWarning: The `disp` argument is deprecated and will be removed in SciPy 1.18.0.
#   covmean, _ = linalg.sqrtm(sigma1.dot(sigma2), disp=False)
# FID:  18.24257896294688

# %% [markdown]
# ## Evaluate (SSIM)
#
# Matched-seed comparison between pretrained and pruned samples (same index = same starting noise).

# %%
# !pip install pytorch-msssim
# Out:
# Collecting pytorch-msssim
#   Downloading pytorch_msssim-1.0.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from pytorch-msssim) (2.11.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (3.29.7)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->pytorch-msssim) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->pytorch-msssim) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->pytorch-msssim) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->pytorch-msssim) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->pytorch-msssim) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->pytorch-msssim) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->pytorch-msssim) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->pytorch-msssim) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->pytorch-msssim) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->pytorch-msssim) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->pytorch-msssim) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->pytorch-msssim) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch->pytorch-msssim) (1.5.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->pytorch-msssim) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->pytorch-msssim) (3.0.3)
# Downloading pytorch_msssim-1.0.0-py3-none-any.whl (7.7 kB)
# Installing collected packages: pytorch-msssim
# Successfully installed pytorch-msssim-1.0.0

# %%
# !python ddpm_exp/compute_ssim.py --path run/sample/ddpm_cifar10_pretrained/process_0 run/sample/ddpm_cifar10_pruned/process_0
# Out:
# run/sample/ddpm_cifar10_pretrained/process_0 run/sample/ddpm_cifar10_pruned/process_0
# 1920 1920
# 20it [00:00, 27.84it/s]
# path1: run/sample/ddpm_cifar10_pretrained/process_0, path2: run/sample/ddpm_cifar10_pruned/process_0, ssim: 0.8872940540313721, mse: 0.004494612105190754
